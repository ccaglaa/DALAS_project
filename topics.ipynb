# %%
import requests
from bs4 import BeautifulSoup

def scrape_ted_topics():
    """
    Scrapes all topics from the TED topics page.
    """
    # The URL of the page to scrape
    url = "https://www.ted.com/topics"

    try:
        # Send an HTTP GET request to the URL
        response = requests.get(url)
        # Raise an exception for bad status codes (4xx or 5xx)
        response.raise_for_status()

        # Parse the HTML content of the page with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all the <a> tags that contain the topic links.
        # Based on the site's structure, these links have the class 'ga-topic-link'.
        topic_elements = soup.find_all('a', class_='ga-topic-link')

        # Extract the text from each element and store it in a list
        topics = [element.get_text(strip=True) for element in topic_elements]

        # Print all the scraped topics
        if topics:
            print("Successfully scraped TED topics:")
            for topic in topics:
                print(f"- {topic}")
        else:
            print("No topics found. The page structure might have changed.")

    except requests.exceptions.RequestException as e:
        print(f"An error occurred during the HTTP request: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    scrape_ted_topics()
# Out:
# No topics found. The page structure might have changed.

# %%
import requests
from bs4 import BeautifulSoup
import re

def scrape_ted_topics_updated():
    """
    Scrapes all topics from the TED topics page using a more robust selector.
    """
    # The URL of the page to scrape
    url = "https://www.ted.com/topics"

    try:
        # Send an HTTP GET request to the URL
        response = requests.get(url)
        # Raise an exception for bad status codes (4xx or 5xx)
        response.raise_for_status()

        # Parse the HTML content of the page with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all <a> tags whose 'href' attribute starts with "/topics/"
        # This is more stable than relying on a CSS class.
        topic_elements = soup.select('a[href^="/topics/"]')

        # Extract the text from each element. We filter out any empty strings.
        topics = [element.get_text(strip=True) for element in topic_elements if element.get_text(strip=True)]

        # Print all the scraped topics
        if topics:
            print("Successfully scraped TED topics:")
            for topic in sorted(topics): # Sorting the list alphabetically
                print(f"- {topic}")
        else:
            print("No topics found. The page structure might have changed again.")

    except requests.exceptions.RequestException as e:
        print(f"An error occurred during the HTTP request: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    scrape_ted_topics_updated()
# Out:
# Successfully scraped TED topics:
# - 3D printing
# - AI
# - AIDS
# - Activism
# - Adaptation
# - Addiction
# - Africa
# - Aging
# - Agriculture
# - Algorithm
# - Aliens
# - Alzheimer's
# - Ancient world
# - Animals
# - Animation
# - Antarctica
# - Anthropocene
# - Anthropology
# - Archaeology
# - Architecture
# - Art
# - Artificial intelligence
# - Asia
# - Asteroid
# - Astrobiology
# - Astronomy
# - Atheism
# - Augmented reality
# - Autism spectrum disorder
# - Bacteria
# - Beauty
# - Bees
# - Behavioral economics
# - Best of the Web
# - Big Bang
# - Biodiversity
# - Bioethics
# - Biology
# - Biomimicry
# - Bionics
# - Biosphere
# - Biotech
# - Birds
# - Blindness
# - Blockchain
# - Body language
# - Books
# - Botany
# - Brain
# - Brazil
# - Buddhism
# - Bullying
# - Business
# - CRISPR
# - Cancer
# - Capitalism
# - Career
# - Chemistry
# - China
# - Christianity
# - Cities
# - Climate change
# - Code
# - Cognitive science
# - Collaboration
# - Comedy
# - Communication
# - Community
# - Compassion
# - Competition
# - Computers
# - Conducting
# - Confidence
# - Consciousness
# - Conservation
# - Consumerism
# - Coral reefs
# - Coronavirus
# - Corruption
# - Countdown
# - Creativity
# - Crime
# - Crowdsourcing
# - Cryptocurrency
# - Culture
# - Curiosity
# - Current events
# - Cyber security
# - DNA
# - Dance
# - Dark matter
# - Data
# - Death
# - Decision-making
# - Deextinction
# - Demo
# - Democracy
# - Depression
# - Design
# - Dinosaurs
# - Disability
# - Discovery
# - Disease
# - Diversity
# - Driverless cars
# - Drones
# - Drugs
# - Ebola
# - Ecology
# - Economics
# - Education
# - Egypt
# - Electricity
# - Emotions
# - Empathy
# - Encryption
# - Energy
# - Engineering
# - Entertainment
# - Entrepreneur
# - Environment
# - Equality
# - Ethics
# - Europe
# - Evolution
# - Exercise
# - Exploration
# - Family
# - Farming
# - Fashion
# - Fear
# - Feminism
# - Film
# - Finance
# - Fish
# - Flight
# - Food
# - Forensics
# - Fossil fuels
# - Friendship
# - Fungi
# - Future
# - Gaming
# - Gardening
# - Gender
# - Genetics
# - Geography
# - Geology
# - Glaciers
# - Global issues
# - Goals
# - Government
# - Grammar
# - Graphic design
# - Growing up
# - Happiness
# - Health
# - Health care
# - Hearing
# - Heart
# - Heart health
# - Hinduism
# - History
# - Homelessness
# - Human body
# - Human rights
# - Humanities
# - Humanity
# - Humor
# - Ideas
# - Identity
# - Illness
# - Illusion
# - Immigration
# - Inclusion
# - India
# - Indigenous peoples
# - Industrial design
# - Infrastructure
# - Innovation
# - Insects
# - International development
# - International relations
# - Internet
# - Interview
# - Invention
# - Investing
# - Islam
# - Journalism
# - Judaism
# - Justice system
# - Kids
# - LGBTQIA+
# - Language
# - Law
# - Leadership
# - Library
# - Life
# - Literature
# - Love
# - Machine learning
# - Magic
# - Manufacturing
# - Maps
# - Marine biology
# - Marketing
# - Mars
# - Math
# - Media
# - Medical imaging
# - Medical research
# - Medicine
# - Meditation
# - Memory
# - Menopause
# - Mental health
# - Metaverse
# - Microbes
# - Microbiology
# - Middle East
# - Military
# - Mindfulness
# - Mission Blue
# - Money
# - Moon
# - Motivation
# - Museums
# - Music
# - NASA
# - NFTs
# - Nanotechnology
# - Natural disaster
# - Natural resources
# - Nature
# - Neurology
# - Neuroscience
# - Nuclear energy
# - Ocean
# - Online privacy
# - PTSD
# - Pain
# - Painting
# - Paleontology
# - Pandemic
# - Parenting
# - Perf
# - Performance
# - Personal growth
# - Personality
# - Philanthropy
# - Philosophy
# - Photography
# - Physics
# - Planets
# - Plants
# - Plastic
# - Poe
# - Poetry
# - Policy
# - Politics
# - Pollution
# - Potential
# - Poverty
# - Pregnancy
# - Primates
# - Prison
# - Product design
# - Productivity
# - Prosthetics
# - Protest
# - Psychology
# - Public health
# - Public space
# - Public speaking
# - Quantum
# - Race
# - Refugees
# - Relationships
# - Religion
# - Renewable energy
# - Reproductive health
# - Resources
# - Rivers
# - Robots
# - Rocket science
# - Science
# - Science fiction
# - Self
# - Sex
# - Sexual violence
# - Shopping
# - Sight
# - Slavery
# - Sleep
# - Smell
# - Soccer
# - Social change
# - Social media
# - Society
# - Sociology
# - Software
# - Solar energy
# - Solar system
# - Sound
# - South America
# - Space
# - Spirituality
# - Spoken word
# - Sports
# - Statistics
# - Storytelling
# - Street art
# - String theory
# - Success
# - Suicide
# - Sun
# - Surgery
# - Surveillance
# - Sustainability
# - Synthetic biology
# - TED Books
# - TED Connects
# - TED Fellows
# - TED Membership
# - TED Prize
# - TED Residency
# - TED en Español
# - TED-Ed
# - TEDMED
# - TEDx
# - TV
# - Teaching
# - Tech
# - Technology
# - Ted health podcast
# - Teenagers
# - Telescopes
# - Television
# - Terrorism
# - The Audacious Project
# - Theater
# - Therapy
# - Time
# - Toys
# - Transgender
# - Transportation
# - Travel
# - Trees
# - Trust
# - Typography
# - UX design
# - United States
# - Universe
# - Urban planning
# - Vaccines
# - Veganism
# - Violence
# - Virtual reality
# - Virus
# - Visualizations
# - Vulnerability
# - War
# - Water
# - Weather
# - Wildlife
# - Wind energy
# - Women
# - Women in business
# - Work
# - Work-life balance
# - Worklife
# - Writing
# - Youth

# %%
import requests
from bs4 import BeautifulSoup
import csv

def scrape_and_save_ted_topics():
    """
    Scrapes all topics from the TED topics page and saves them to a CSV file.
    """
    url = "https://www.ted.com/topics"
    # Define the name of the output CSV file
    filename = "ted_topics.csv"

    try:
        # 1. Scrape the webpage
        response = requests.get(url)
        response.raise_for_status()  # Check for request errors

        soup = BeautifulSoup(response.text, 'html.parser')
        topic_elements = soup.select('a[href^="/topics/"]')
        topics = [element.get_text(strip=True) for element in topic_elements if element.get_text(strip=True)]

        if not topics:
            print("No topics found. The page structure might have changed.")
            return

        # 2. Write the data to a CSV file
        with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
            # Create a CSV writer object
            writer = csv.writer(csvfile)

            # Write the header row
            writer.writerow(['Topic'])

            # Write the topic data, one topic per row
            for topic in sorted(topics):
                writer.writerow([topic])

        print(f"✅ Success! Scraped {len(topics)} topics and saved them to '{filename}'.")

    except requests.exceptions.RequestException as e:
        print(f"❌ An error occurred during the HTTP request: {e}")
    except IOError as e:
        print(f"❌ An error occurred while writing the file: {e}")
    except Exception as e:
        print(f"❌ An unexpected error occurred: {e}")

if __name__ == "__main__":
    scrape_and_save_ted_topics()
# Out:
# ✅ Success! Scraped 373 topics and saved them to 'ted_topics.csv'.

# %%
import re
from html import unescape
import pandas as pd

# %%
with open('test3.rtf', 'r', encoding='utf-8') as f:
    content = f.read()

# %%
# Extract video information using regex patterns
videos = []

# Pattern to find video links with titles, speakers, and duration
pattern = r'href="(/talks/[^"]+)"[^>]*>.*?alt="([^"]*)".*?dir="ltr">(\d+:\d+)</span>.*?dir="ltr">([^<]+)</span>.*?dir="ltr">([^<]+)</p>'

matches = re.findall(pattern, content, re.DOTALL)

# %%
for match in matches:
    url_path = match[0]
    alt_text = unescape(match[1])
    duration = match[2]
    title = unescape(match[3])
    speaker = unescape(match[4])
    
    video_data = {
        'title': title.strip(),
        'speaker': speaker.strip(),
        'duration': duration,
        'url': f'https://ted.com{url_path}'
    }
    videos.append(video_data)

# %%
# Create DataFrame
df = pd.DataFrame(videos)

# Display DataFrame info
print(f"Found {len(df)} TED Talk videos\n")
print("DataFrame Shape:", df.shape)
print("\nFirst 5 rows:")
print(df.head())

print("\nDataFrame Info:")
print(df.info())

# Optional: Save to CSV
df.to_csv('ted_talks.csv', index=False, encoding='utf-8')
print("\n✓ Data saved to ted_talks.csv")

# Optional: Save to Excel
df.to_excel('ted_talks.xlsx', index=False)
print("✓ Data saved to ted_talks.xlsx")

df
# Out:
# Found 24 TED Talk videos
#
# DataFrame Shape: (24, 4)
#
# First 5 rows:
#                                                title  \
# 0  A pastry chef works his chocolatier magic \'97...
# 1                 This TED Talk is full of bad ideas
# 2  What will the future of art look like? A visua...
# 3  Beyond the Talk: Salome Agbaroji and Samora Pi...
# 4         300 years of classical music in 18 minutes
#
#                                    speaker duration  \
# 0                           Amaury Guichon    12:33
# 1                              Gabe Whaley    11:19
# 2             Rob Bredow and Nora Atkinson    24:48
# 3  Salome Agbaroji and Samora Pinderhughes    45:20
# 4                              Joshua Bell    18:07
#
#                                                  url
# 0  https://ted.com/talks/amaury_guichon_a_pastry_...
# 1  https://ted.com/talks/gabe_whaley_this_ted_tal...
# 2  https://ted.com/talks/rob_bredow_and_nora_atki...
# 3  https://ted.com/talks/salome_agbaroji_and_samo...
# 4  https://ted.com/talks/joshua_bell_300_years_of...
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     24 non-null     object
#  1   speaker   24 non-null     object
#  2   duration  24 non-null     object
#  3   url       24 non-null     object
# dtypes: object(4)
# memory usage: 896.0+ bytes
# None
#
# ✓ Data saved to ted_talks.csv
# ✓ Data saved to ted_talks.xlsx
#                                                 title  \
# 0   A pastry chef works his chocolatier magic \'97...
# 1                  This TED Talk is full of bad ideas
# 2   What will the future of art look like? A visua...
# 3   Beyond the Talk: Salome Agbaroji and Samora Pi...
# 4          300 years of classical music in 18 minutes
# 5                 A multigenerational musical journey
# 6                                Is AI ruining music?
# 7             How to turn AI prompts into movie magic
# 8   Why meeting in the middle isn\'92t enough for ...
# 9   The inside story of Notre-Dame\'92s incredible...
# 10  The fire-breathing dragon-horse sparking wonde...
# 11  TED Talks Daily Book Club: A Little Daylight Left
# 12                     A musical duet with AI herself
# 13                 The science and art of uncertainty
# 14  Forget hustle culture. Behold the Artist Corpo...
# 15  The case for making art when the world is on fire
# 16  How can creativity help us heal? A doctor and ...
# 17     How I turned frustration into creative success
# 18  What if the climate movement felt like a house...
# 19               How art helped me grapple with grief
# 20  The artist-driven innovation behind the films ...
# 21       The role of art and forgiveness in democracy
# 22                         "Remember Me" / "happy im"
# 23    A survival guide for musicians in the age of AI
#
#                                               speaker duration  \
# 0                                      Amaury Guichon    12:33
# 1                                         Gabe Whaley    11:19
# 2                        Rob Bredow and Nora Atkinson    24:48
# 3             Salome Agbaroji and Samora Pinderhughes    45:20
# 4                                         Joshua Bell    18:07
# 5                                            Yijia Tu    09:38
# 6                                      Dustin Ballard    11:15
# 7                                          Jason Zada    11:22
# 8                        Bill Heck and Stephanie Lepp    11:24
# 9                                 Philippe Villeneuve    12:59
# 10                                 Fr\'e9dette Lampre    11:37
# 11                                          Sarah Kay    52:04
# 12                       Todd Almond and Donna Murphy    09:18
# 13  Amma Y. Ghartey-Tagoe Kootin, Shohini Ghose an...    29:33
# 14                                   Yancey Strickler    10:26
# 15                                         Amie McNee    13:28
# 16                    Amy Baxter and Navied Mahdavian    22:38
# 17                                   Joshua Schachter    04:45
# 18                                   Matthew Phillips    08:34
# 19                                   Navied Mahdavian    08:01
# 20                                         Rob Bredow    15:31
# 21               Marc Bamuthi Joseph and Wendy Whelan    09:36
# 22                                                UMI    10:21
# 23                                   Harvey Mason jr.    12:51
#
#                                                   url
# 0   https://ted.com/talks/amaury_guichon_a_pastry_...
# 1   https://ted.com/talks/gabe_whaley_this_ted_tal...
# 2   https://ted.com/talks/rob_bredow_and_nora_atki...
# 3   https://ted.com/talks/salome_agbaroji_and_samo...
# 4   https://ted.com/talks/joshua_bell_300_years_of...
# 5   https://ted.com/talks/yijia_tu_a_multigenerati...
# 6   https://ted.com/talks/dustin_ballard_is_ai_rui...
# 7   https://ted.com/talks/jason_zada_how_to_turn_a...
# 8   https://ted.com/talks/bill_heck_and_stephanie_...
# 9   https://ted.com/talks/philippe_villeneuve_the_...
# 10  https://ted.com/talks/fredette_lampre_the_fire...
# 11  https://ted.com/talks/sarah_kay_ted_talks_dail...
# 12  https://ted.com/talks/todd_almond_and_donna_mu...
# 13  https://ted.com/talks/amma_y_ghartey_tagoe_koo...
# 14  https://ted.com/talks/yancey_strickler_forget_...
# 15  https://ted.com/talks/amie_mcnee_the_case_for_...
# 16  https://ted.com/talks/amy_baxter_and_navied_ma...
# 17  https://ted.com/talks/joshua_schachter_how_i_t...
# 18  https://ted.com/talks/matthew_phillips_what_if...
# 19  https://ted.com/talks/navied_mahdavian_how_art...
# 20  https://ted.com/talks/rob_bredow_the_artist_dr...
# 21  https://ted.com/talks/marc_bamuthi_joseph_and_...
# 22     https://ted.com/talks/umi_remember_me_happy_im
# 23  https://ted.com/talks/harvey_mason_jr_a_surviv...

# %%
with open('12-18.rtf', 'r', encoding='utf-8') as f:
    content = f.read()

# %%
# Extract video information using regex patterns
videos = []

# Pattern to find video links with titles, speakers, and duration
pattern = r'href="(/talks/[^"]+)"[^>]*>.*?alt="([^"]*)".*?dir="ltr">(\d+:\d+)</span>.*?dir="ltr">([^<]+)</span>.*?dir="ltr">([^<]+)</p>'

matches = re.findall(pattern, content, re.DOTALL)

for match in matches:
    url_path = match[0]
    alt_text = unescape(match[1])
    duration = match[2]
    title = unescape(match[3])
    speaker = unescape(match[4])
    
    video_data = {
        'title': title.strip(),
        'speaker': speaker.strip(),
        'duration': duration,
        'url': f'https://ted.com{url_path}'
    }
    videos.append(video_data)

# %%
# Create DataFrame
df = pd.DataFrame(videos)

# Display DataFrame info
print(f"Found {len(df)} TED Talk videos\n")
print("DataFrame Shape:", df.shape)
print("\nFirst 5 rows:")
df.head()

print("\nDataFrame Info:")
df.info()

# Optional: Save to CSV
df.to_csv('ted_talks12-18.csv', index=False, encoding='utf-8')
print("\n✓ Data saved to ted_talks12-18.csv")
# Out:
# Found 2265 TED Talk videos
#
# DataFrame Shape: (2265, 4)
#
# First 5 rows:
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     2265 non-null   object
#  1   speaker   2265 non-null   object
#  2   duration  2265 non-null   object
#  3   url       2265 non-null   object
# dtypes: object(4)
# memory usage: 70.9+ KB
#
# ✓ Data saved to ted_talks12-18.csv

# %%
df
# Out:
#                                                   title              speaker  \
# 0     A pastry chef works his chocolatier magic \'97...       Amaury Guichon
# 1              The flourishing future of women's sports         Kate Johnson
# 2     How we\'92re turning pollution into toys, toot...               Xu Hao
# 3     The best thing that could happen to the energy...        Matt Tilleard
# 4     3 simple ways to build stronger relationships ...      Alyssa Birnbaum
# ...                                                 ...                  ...
# 2260            Meet the founder of the blog revolution           Mena Trott
# 2261                      Simple designs to save a life            Amy Smith
# 2262                               One Laptop per Child  Nicholas Negroponte
# 2263                                  Letting go of God        Julia Sweeney
# 2264                        Averting the climate crisis              Al Gore
#
#      duration                                                url
# 0       12:33  https://ted.com/talks/amaury_guichon_a_pastry_...
# 1       12:48  https://ted.com/talks/kate_johnson_the_flouris...
# 2       12:53  https://ted.com/talks/xu_hao_how_we_re_turning...
# 3       12:41  https://ted.com/talks/matt_tilleard_the_best_t...
# 4       14:59  https://ted.com/talks/alyssa_birnbaum_3_simple...
# ...       ...                                                ...
# 2260    16:29  https://ted.com/talks/mena_trott_meet_the_foun...
# 2261    14:42  https://ted.com/talks/amy_smith_simple_designs...
# 2262    17:20  https://ted.com/talks/nicholas_negroponte_one_...
# 2263    16:15  https://ted.com/talks/julia_sweeney_letting_go...
# 2264    15:54  https://ted.com/talks/al_gore_averting_the_cli...
#
# [2265 rows x 4 columns]
